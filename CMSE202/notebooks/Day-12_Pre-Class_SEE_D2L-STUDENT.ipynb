# %% [markdown]
# # Pre-Class Assignment: Reviewing Project Ideas
# # Day 12
# # CMSE 202

# %% [markdown]
# **Download the pre-class assignment for Day 12 on D2L.**  Each section will have a unique file with the project ideas for that section.

# %% [markdown]
# ---
#
# &#169; Copyright 2026,  Department of Computational Mathematics, Science and Engineering at Michigan State University
